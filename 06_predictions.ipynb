# %%
import cv2
from face_recognition import faceRcognitionPipeline
import matplotlib.pyplot as plt

# %% [markdown]
# ### Face recognition prediction

# %%
pred_img, pred_dict = faceRcognitionPipeline('./test_images/test_04.png')

# %%
cv2.imshow("Predicted Image", pred_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 2025-03-06 13:43:02.276 python[69361:1441392] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-06 13:43:02.276 python[69361:1441392] +[IMKInputSession subclass]: chose IMKInputSession_Modern

# %%
img_rgb = cv2.cvtColor(pred_img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10, 10))
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# generate report
for i in range(len(pred_dict)):
    obj_gray = pred_dict[i]['roi']
    obj_eig = pred_dict[i]['eig_img'].reshape(100,100)
    plt.subplot(1,2,1)
    plt.imshow(obj_gray, cmap='gray')
    plt.title('Grayscale Image')
    plt.subplot(1,2,2)
    plt.imshow(obj_eig, cmap='gray')
    plt.title('Eigen Image')
    
    plt.show()
    
    print(f'Predicted Gender = {pred_dict[i]['prediction_name']}')
    print(f'Predicted Score = {pred_dict[i]['score']}')
# Out:
# Predicted Gender = male
# Predicted Score = 0.89
# Predicted Gender = female
# Predicted Score = 0.96

# %% [markdown]
# ## Real Time Gender Recognition

# %%
cap = cv2.VideoCapture(0)

while True:
    ret, frame= cap.read()
    
    if ret == False:
        break
    
    pred_img, pred_dict =  faceRcognitionPipeline(frame, path=False)
    cv2.imshow('prediction', pred_img)
    
    if cv2.waitKey(1) == ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# 2025-03-06 13:50:21.297 python[69963:1462352] +[IMKClient subclass]: chose IMKClient_Modern
# 2025-03-06 13:50:21.297 python[69963:1462352] +[IMKInputSession subclass]: chose IMKInputSession_Modern
